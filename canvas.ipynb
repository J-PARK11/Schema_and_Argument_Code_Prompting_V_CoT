# %%
import os
import json
import dataframe_image as dfi
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Seaborn 스타일 설정
sns.set(style="whitegrid")
colors = sns.color_palette("husl", 40)

# %%
with open(os.path.join('/data/jhpark_checkpoint/schema_and_argument_ckpt/official_classification/supervised/img_baseline', 'train_loss.json')) as f:
    train_loss = json.load(f)

# %%
def plot_loss(train_loss, epochs, save_path=None):

    # 그래프 그리기
    plt.figure(figsize=(10, 6))
    
    # 학습 로스
    train_xticks = list(map(int,list(train_loss.keys())))
    train_xvalues = list(train_loss.values())
    plt.plot(train_xticks, train_xvalues, 'b-', label='Training Loss', linewidth=2)
    
    # 그래프 제목과 레이블 설정
    plt.title('Training Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Steps', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    
    # 범례 및 기타 설정
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.tight_layout()

plot_loss(train_loss,1)

# %%
data_reorganized = {
    "Avg. 2nd Grader Performance": {
        "Count": "72.8",
        "Arithmetic": "81.3",
        "Logic": "82.2",
        "Path Trace": "81.1",
        "Algebra": "64.5",
        "Measure": "90.4",
        "Spatial": "74.8",
        "Pattern Finding": "88.6",
        "Average": "77.1"
    },
    "Greedy (baseline)": {
        "Count": "21.7/22.6",
        "Arithmetic": "8.97/21.5",
        "Logic": "18.5/21.0",
        "Path Trace": "22.7/21.2",
        "Algebra": "10.2/21.1",
        "Measure": "12.8/21.1",
        "Spatial": "22.3/21.3",
        "Pattern Finding": "20.6/21.3",
        "Average": "17.3/21.6"
    },
    "Uniform (baseline)": {
        "Count": "9.41/20.0",
        "Arithmetic": "3.65/20.0",
        "Logic": "7.91/20.0",
        "Path Trace": "11.1/20.0",
        "Algebra": "5.01/20.0",
        "Measure": "3.63/20.0",
        "Spatial": "15.5/20.0",
        "Pattern Finding": "16.7/20.0",
        "Average": "8.41/20.0"
    },
    "Swin-T + Emb.": {
        "Count": "23.1/35.1",
        "Arithmetic": "33.7/41.0",
        "Logic": "20.3/28.8",
        "Path Trace": "16.7/18.6",
        "Algebra": "17.7/29.5",
        "Measure": "26.3/34.3",
        "Spatial": "24.5/29.1",
        "Pattern Finding": "17.5/26.5",
        "Average": "22.5/30.8"
    },
    "Swin-B + Emb.": {
        "Count": "22.0/34.0",
        "Arithmetic": "29.4/36.5",
        "Logic": "17.7/26.1",
        "Path Trace": "16.7/17.0",
        "Algebra": "17.1/30.2",
        "Measure": "25.0/34.2",
        "Spatial": "26.2/30.7",
        "Pattern Finding": "21.5/29.6",
        "Average": "21.6/29.9"
    },
    "Cross-Transformer + Emb.": {
        "Count": "20.5/30.4",
        "Arithmetic": "6.3/15.3",
        "Logic": "15.5/22.9",
        "Path Trace": "15.1/15.6",
        "Algebra": "8.7/23.9",
        "Measure": "10.7/18.2",
        "Spatial": "21.7/24.7",
        "Pattern Finding": "19.0/27.3",
        "Average": "14.7/22.8"
    },
    "ViT-16 + Emb.": {
        "Count": "25.6/36.4",
        "Arithmetic": "39.7/47.1",
        "Logic": "21.2/30.8",
        "Path Trace": "15.5/16.3",
        "Algebra": "20.1/33.8",
        "Measure": "39.4/40.8",
        "Spatial": "29.0/33.0",
        "Pattern Finding": "20.3/29.6",
        "Average": "25.9/35.5"
    },
    "MAE + Emb.": {
        "Count": "25.4/36.7",
        "Arithmetic": "34.2/43.2",
        "Logic": "21.6/31.5",
        "Path Trace": "16.4/16.7",
        "Algebra": "20.3/33.3",
        "Measure": "32.0/39.7",
        "Spatial": "28.2/32.9",
        "Pattern Finding": "18.6/26.6",
        "Average": "24.5/33.0"
    },
    "SimSiam + Emb.": {
        "Count": "39.9/49.4",
        "Arithmetic": "8.61/19.2",
        "Logic": "40.2/49.7",
        "Path Trace": "24.1/26.1",
        "Algebra": "14.1/23.2",
        "Measure": "29.5/39.6",
        "Spatial": "34.3/37.2",
        "Pattern Finding": "37.5/43.7",
        "Average": "27.6/35.3"
    },
    "R18 + Emb.": {
        "Count": "44.0/54.0",
        "Arithmetic": "8.8/19.8",
        "Logic": "41.1/47.6",
        "Path Trace": "24.5/26.7",
        "Algebra": "13.7/26.5",
        "Measure": "30.9/40.2",
        "Spatial": "43.3/45.5",
        "Pattern Finding": "29.5/34.8",
        "Average": "29.4/37.4"
    },
    "R50 + Emb.": {
        "Count": "42.1/51.9",
        "Arithmetic": "8.47/19.6",
        "Logic": "41.3/47.7",
        "Path Trace": "25.1/27.1",
        "Algebra": "12.8/22.6",
        "Measure": "32.9/42.8",
        "Spatial": "45.6/48.0",
        "Pattern Finding": "41.8/47.9",
        "Average": "29.7/37.3"
    },
    "R50 + GloVe": {
        "Count": "46.0/56.3",
        "Arithmetic": "39.2/48.5",
        "Logic": "53.9/56.4",
        "Path Trace": "26.7/28.9",
        "Algebra": "21.5/32.4",
        "Measure": "58.9/68.5",
        "Spatial": "48.5/50.4",
        "Pattern Finding": "43.3/47.8",
        "Average": "40.0/47.2"
    },
    "R50 + GPT2": {
        "Count": "47.0/57.9",
        "Arithmetic": "44.8/53.1",
        "Logic": "55.1/58.6",
        "Path Trace": "26.1/28.4",
        "Algebra": "27.2/39.3",
        "Measure": "61.0/71.3",
        "Spatial": "49.0/50.2",
        "Pattern Finding": "42.5/48.4",
        "Average": "42.1/49.6"
    },
    "R50 + BERT": {
        "Count": "48.5/59.3",
        "Arithmetic": "46.1/54.9",
        "Logic": "56.7/60.2",
        "Path Trace": "26.5/28.4",
        "Algebra": "28.5/39.7",
        "Measure": "65.6/75.4",
        "Spatial": "44.3/46.2",
        "Pattern Finding": "39.9/45.3",
        "Average": "42.8/50.2"
    },
    "CLIP": {
        "Count": "41.3/52.9",
        "Arithmetic": "18.2/29.3",
        "Logic": "33.3/41.1",
        "Path Trace": "19.8/21.9",
        "Algebra": "12.9/24.9",
        "Measure": "27.8/42.8",
        "Spatial": "32.2/36.2",
        "Pattern Finding": "29.9/36.1",
        "Average": "27.3/36.4"
    },
    "FLAVA": {
        "Count": "47.7/58.1",
        "Arithmetic": "20.2/29.7",
        "Logic": "41.4/47.1",
        "Path Trace": "25.4/27.1",
        "Algebra": "19.6/31.2",
        "Measure": "30.5/41.9",
        "Spatial": "33.2/35.7",
        "Pattern Finding": "38.3/44.2",
        "Average": "32.3/40.2"
    },
    "Option Generation": {
        "Count": "x",
        "Arithmetic": "41.00",
        "Logic": "47.0",
        "Path Trace": "54.0",
        "Algebra": "33.33",
        "Measure": "47.00",
        "Spatial": "34.0",
        "Pattern Finding": "x",
        "Average": "45.29"
    },
    "Value Generation with opt prompt": {
        "Count": "x",
        "Arithmetic": "48.33",
        "Logic": "45.5",
        "Path Trace": "52.0",
        "Algebra": "22.0",
        "Measure": "49.0",
        "Spatial": "40.0",
        "Pattern Finding": "x",
        "Average": "45.18"
    },
    "Value Generation w/o opt prompt": {
        "Count": "x",
        "Arithmetic": "30.0",
        "Logic": "35.0",
        "Path Trace": "46.0",
        "Algebra": "26.67",
        "Measure": "50.0",
        "Spatial": "46.0",
        "Pattern Finding": "x",
        "Average": "38.94"
    }
}

sorted_data = dict(sorted(
    data_reorganized.items(),
    key=lambda item: float(item[1]["Average"].split('/')[0]),
    reverse=False
))

# DataFrame으로 변환
df = pd.DataFrame(sorted_data).T

# 색칠
def color_ours(idx):
    if "Generation" in idx:
        color = "background-color: blue;"
    # elif 'Swin' in idx:
    #     color = "background-color: red;"
    elif '2nd' in idx:
        color = "background-color: green;"
    else:
        color = None
    return color

styled_df = df.style.map_index(color_ours)

# 표 출력
styled_df
# Out:
# <style type="text/css">
# #T_7bf04_level0_row3, #T_7bf04_level0_row4 {
#   background-color: red;
# }
# #T_7bf04_level0_row12, #T_7bf04_level0_row16, #T_7bf04_level0_row17 {
#   background-color: blue;
# }
# #T_7bf04_level0_row18 {
#   background-color: green;
# }
# </style>
# <table id="T_7bf04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bf04_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_7bf04_level0_col1" class="col_heading level0 col1" >Arithmetic</th>
#       <th id="T_7bf04_level0_col2" class="col_heading level0 col2" >Logic</th>
#       <th id="T_7bf04_level0_col3" class="col_heading level0 col3" >Path Trace</th>
#       <th id="T_7bf04_level0_col4" class="col_heading level0 col4" >Algebra</th>
#       <th id="T_7bf04_level0_col5" class="col_heading level0 col5" >Measure</th>
#       <th id="T_7bf04_level0_col6" class="col_heading level0 col6" >Spatial</th>
# ...

# %%
# 데이터를 pandas DataFrame으로 변환
data_reorganized = {
    "Avg. 2nd Grader Performance": {
        "Count": "72.8",
        "Arithmetic": "81.3",
        "Logic": "82.2",
        "Path Trace": "81.1",
        "Algebra": "64.5",
        "Measure": "90.4",
        "Spatial": "74.8",
        "Pattern Finding": "88.6",
        "Average": "77.1"
    },
    "Greedy (baseline)": {
        "Count": "19.1/21.4",
        "Arithmetic": "14.0/21.4",
        "Logic": "18.5/21.1",
        "Path Trace": "21.8/21.1",
        "Algebra": "13.5/21.5",
        "Measure": "23.1/20.9",
        "Spatial": "18.2/21.2",
        "Pattern Finding": "21.4/21.4",
        "Average": "17.7/21.3"
    },
    "Uniform (baseline)": {
        "Count": "7.74/20.0",
        "Arithmetic": "8.00/20.0",
        "Logic": "7.61/20.0",
        "Path Trace": "18.9/20.0",
        "Algebra": "6.94/20.0",
        "Measure": "5.62/20.0",
        "Spatial": "14.2/20.0",
        "Pattern Finding": "20.0/20.0",
        "Average": "11.2/20.0"
    },
    "MAE + BERT": {
        "Count": "5.89/19.1",
        "Arithmetic": "5.24/26.7",
        "Logic": "5.23/25.9",
        "Path Trace": "0.0/0.0",
        "Algebra": "8.34/17.9",
        "Measure": "0.0/0.0",
        "Spatial": "2.85/10.6",
        "Pattern Finding": "0.0/0.0",
        "Average": "4.74/17.4"
    },
    "SimSiam + BERT": {
        "Count": "6.44/18.3",
        "Arithmetic": "7.14/22.4",
        "Logic": "6.56/27.0",
        "Path Trace": "6.54/18.5",
        "Algebra": "3.62/24.5",
        "Measure": "12.1/26.7",
        "Spatial": "14.8/23.4",
        "Pattern Finding": "0.0/21.2",
        "Average": "8.09/23.8"
    },
    "Swin_T + BERT": {
        "Count": "8.02/12.5",
        "Arithmetic": "3.14/20.1",
        "Logic": "10.1/23.9",
        "Path Trace": "17.1/20.4",
        "Algebra": "6.77/21.3",
        "Measure": "11.1/21.9",
        "Spatial": "12.4/17.6",
        "Pattern Finding": "21.3/21.3",
        "Average": "9.49/20.2"
    },
    "ViT-16 + BERT": {
        "Count": "9.41/22.7",
        "Arithmetic": "5.77/26.8",
        "Logic": "6.95/25.1",
        "Path Trace": "4.72/18.7",
        "Algebra": "5.57/15.1",
        "Measure": "8.68/21.3",
        "Spatial": "11.6/21.5",
        "Pattern Finding": "18.9/19.7",
        "Average": "8.51/21.6"
    },
    "CLIP": {
        "Count": "9.04/17.4",
        "Arithmetic": "3.70/19.9",
        "Logic": "8.50/25.9",
        "Path Trace": "25.9/25.9",
        "Algebra": "8.36/30.0",
        "Measure": "9.42/22.9",
        "Spatial": "15.9/21.7",
        "Pattern Finding": "22.9/22.9",
        "Average": "11.9/24.1"
    },
    "FLAVA": {
        "Count": "12.0/29.6",
        "Arithmetic": "2.90/18.4",
        "Logic": "7.27/28.0",
        "Path Trace": "8.70/28.4",
        "Algebra": "1.99/28.2",
        "Measure": "7.40/11.6",
        "Spatial": "6.70/11.6",
        "Pattern Finding": "0.0/0.0",
        "Average": "7.35/25.2"
    },
    "R50 + BERT (FT + Cls.)": {
        "Count": "10.9/18.3",
        "Arithmetic": "6.96/15.8",
        "Logic": "12.8/20.8",
        "Path Trace": "19.6/19.7",
        "Algebra": "7.95/15.1",
        "Measure": "16.9/26.7",
        "Spatial": "13.4/17.7",
        "Pattern Finding": "0.0/21.2",
        "Average": "11.7/18.9"
    },
    "R50 + BERT (FT + Reg.)": {
        "Count": "12.0/22.8",
        "Arithmetic": "5.08/21.3",
        "Logic": "4.24/16.2",
        "Path Trace": "18.4/18.4",
        "Algebra": "4.89/22.2",
        "Measure": "15.1/25.9",
        "Spatial": "11.9/17.9",
        "Pattern Finding": "19.0/19.0",
        "Average": "8.21/19.7"
    },
    "Option Generation": {
        "Count": "x",
        "Arithmetic": "20.67",
        "Logic": "x",
        "Path Trace": "x",
        "Algebra": "14.33",
        "Measure": "19.33",
        "Spatial": "x",
        "Pattern Finding": "x",
        "Average": "18.11"
    },
    "Value Generation with opt prompt": {
        "Count": "x",
        "Arithmetic": "27.33",
        "Logic": "x",
        "Path Trace": "x",
        "Algebra": "8.67",
        "Measure": "18.0",
        "Spatial": "x",
        "Pattern Finding": "x",
        "Average": "18.00"
    },
    "Value Generation w/o opt prompt": {
        "Count": "x",
        "Arithmetic": "10.0",
        "Logic": "x",
        "Path Trace": "x",
        "Algebra": "3.67",
        "Measure": "5.00",
        "Spatial": "x",
        "Pattern Finding": "x",
        "Average": "6.22"
    }
}

sorted_data = dict(sorted(
    data_reorganized.items(),
    key=lambda item: float(item[1]["Average"].split('/')[0]),
    reverse=False
))

# DataFrame으로 변환
df = pd.DataFrame(sorted_data).T

# 색칠
def color_ours(idx):
    if "Generation" in idx:
        color = "background-color: blue;"
    # elif 'Swin' in idx:
    #     color = "background-color: red;"
    elif '2nd' in idx:
        color = "background-color: green;"
    else:
        color = None
    return color

styled_df = df.style.map_index(color_ours)

# 표 출력
styled_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /SMART_101/Schema_and_Argument_V_CoT/canvas.ipynb Cell 5 line 1
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6a687061726b5f7177656e325f766c227d@ssh-remote%2B166.104.112.72/SMART_101/Schema_and_Argument_V_CoT/canvas.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=158'>159</a> sorted_data = dict(sorted(
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6a687061726b5f7177656e325f766c227d@ssh-remote%2B166.104.112.72/SMART_101/Schema_and_Argument_V_CoT/canvas.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=159'>160</a>     data_reorganized.items(),
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 설정
data = {
    "Puzzle Category": ["Avg. 2nd Grader Performance", "Greedy (baseline)", "Uniform (baseline)",
                        "MAE + BERT", "SimSiam + BERT", "Swin_T + BERT", "ViT-16 + BERT", 
                        "CLIP", "FLAVA", "R50 + BERT (FT + Cls.)", "R50 + BERT (FT + Reg.)",
                        "Option Generation", "Value Generation with opt prompt", "Value Generation w/o opt prompt"],
    "Count": ["72.8", "19.1/21.4", "7.74/20.0", "5.89/19.1", "6.44/18.3", "8.02/12.5", 
                   "9.41/22.7", "9.04/17.4", "12.0/29.6", "10.9/18.3", "12.0/22.8",
                   'x', 'x', 'x'],
    "Arithmetic": ["81.3", "14.0/21.4", "8.00/20.0", "5.24/26.7", "7.14/22.4", "3.14/20.1", 
              "5.77/26.8", "3.70/19.9", "2.90/18.4", "6.96/15.8", "5.08/21.3",
              '20.67', '27.33', '10.0'],
    "Logic": ["82.2", "18.5/21.1", "7.61/20.0", "5.23/25.9", "6.56/27.0", "10.1/23.9", 
                   "6.95/25.1", "8.50/25.9", "7.27/28.0", "12.8/20.8", "4.24/16.2",
                   'x', 'x', 'x'],
    "Path Trace": ["81.1", "21.8/21.1", "18.9/20.0", "0.0/0.0", "6.54/18.5", "17.1/20.4", 
                "4.72/18.7", "25.9/25.9", "8.70/28.4", "19.6/19.7", "18.4/18.4",
                'x', 'x', 'x'],
    "Algebra": ["64.5", "13.5/21.5", "6.94/20.0", "8.34/17.9", "3.62/24.5", "6.77/21.3", 
                "5.57/15.1", "8.36/30.0", "1.99/28.2", "7.95/15.1", "4.89/22.2",
                '14.33', '8.67', '3.67'],
    "Measure": ["90.4", "23.1/20.9", "5.62/20.0", "0.0/0.0", "12.1/26.7", "11.1/21.9", 
                "8.68/21.3", "9.42/22.9", "7.40/11.6", "16.9/26.7", "15.1/25.9",
                '19.33', '18.0', '5.00'],
    "Spatial": ["74.8", "18.2/21.2", "14.2/20.0", "2.85/10.6", "14.8/23.4", "12.4/17.6", 
                "11.6/21.5", "15.9/21.7", "6.70/11.6", "13.4/17.7", "11.9/17.9",
                'x', 'x', 'x'],
    "Pattern Finding": ["88.6", "21.4/21.4", "20.0/20.0", "0.0/0.0", "0.0/21.2", "21.3/21.3", 
                "18.9/19.7", "22.9/22.9", "0.0/0.0", "0.0/21.2", "19.0/19.0",
                'x', 'x', 'x'],
    "Average": ["77.1", "17.7/21.3", "11.2/20.0", "4.74/17.4", "8.09/23.8", "9.49/20.2", 
                "8.51/21.6", "11.9/24.1", "7.35/25.2", "11.7/18.9", "8.21/19.7",
                "18.11", "18.00", "6.22"]
}


# DataFrame 생성
df = pd.DataFrame(data)

# 시각화 함수 정의
def visualize_table(df):
    fig, ax = plt.subplots(figsize=(12, 5))

    # 테이블 그리기
    ax.axis('off')
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    # 스타일 설정
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.auto_set_column_width(col=list(range(len(df.columns))))

    # 헤더와 첫 행 배경 색상 설정
    num_row = len(df.values)
    for (i, j), cell in table.get_celld().items():
        if i == 0:
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor('#40466e')
        elif i == 1:
            cell.set_facecolor('#e8e8e8')
        elif i in [2,3]:
            cell.set_facecolor('#c9daf8ff')
        elif i >= (num_row+1-3):
            cell.set_facecolor('#f4ccccff')
        else:
            cell.set_facecolor('white')
        cell.set_edgecolor('#bdbdbd')

    plt.title('Zero-Shot Setting Performance Table')
    plt.tight_layout()
    plt.show()

# 함수 실행
visualize_table(df)

# %%
data = {
    "Model": ["Avg. 2nd Grader Performance", "Greedy (baseline)", "Uniform (baseline)", "Swin-T + Emb.", "Swin-B + Emb.", 
              "Cross-Transformer + Emb.", "ViT-16 + Emb.", "MAE + Emb.", 
              "SimSiam + Emb.", "R18 + Emb.", "R50 + Emb.", "R50 + GloVe", 
              "R50 + GPT2", "R50 + BERT", "CLIP", "FLAVA",
              "Option Generation", "Value Generation with opt prompt", "Value Generation w/o opt prompt"],
    "Count": ["72.8", "21.7/22.6", "9.41/20.0", "23.1/35.1", "22.0/34.0", "20.5/30.4", "25.6/36.4", 
              "25.4/36.7", "39.9/49.4", "44.0/54.0", "42.1/51.9", "46.0/56.3", "47.0/57.9", 
              "48.5/59.3", "41.3/52.9", "47.7/58.1", 'x', 'x', 'x'],
    "Arithmetic": ["81.3", "8.97/21.5", "3.65/20.0", "33.7/41.0", "29.4/36.5", "6.3/15.3", "39.7/47.1", 
                   "34.2/43.2", "8.61/19.2", "8.8/19.8", "8.47/19.6", "39.2/48.5", "44.8/53.1", 
                   "46.1/54.9", "18.2/29.3", "20.2/29.7", '41.00', '48.33', '30.0'],
    "Logic": ["82.2", "18.5/21.0", "7.91/20.0", "20.3/28.8", "17.7/26.1", "15.5/22.9", "21.2/30.8", 
              "21.6/31.5", "40.2/49.7", "41.1/47.6", "41.3/47.7", "53.9/56.4", "55.1/58.6", 
              "56.7/60.2", "33.3/41.1", "41.4/47.1", '47.0', '45.5', '35.0'],
    "Path Trace": ["81.1", "22.7/21.2", "11.1/20.0", "16.7/18.6", "16.7/17.0", "15.1/15.6", "15.5/16.3", 
                   "16.4/16.7", "24.1/26.1", "24.5/26.7", "25.1/27.1", "26.7/28.9", "26.1/28.4", 
                   "26.5/28.4", "19.8/21.9", "25.4/27.1", '54.0', '52.0', '46.0'],
    "Algebra": ["64.5", "10.2/21.1", "5.01/20.0", "17.7/29.5", "17.1/30.2", "8.7/23.9", "20.1/33.8", 
                "20.3/33.3", "14.1/23.2", "13.7/26.5", "12.8/22.6", "21.5/32.4", "27.2/39.3", 
                "28.5/39.7", "12.9/24.9", "19.6/31.2", '33.33', '22.0', '26.67'],
    
    "Measure": ["90.4", "12.8/21.1", "3.63/20.0", "26.3/34.3", "25.0/34.2", "10.7/18.2", "39.4/40.8", 
                "32.0/39.7", "29.5/39.6", "30.9/40.2", "32.9/42.8", "58.9/68.5", "61.0/71.3", 
                "65.6/75.4", "27.8/42.8", "30.5/41.9", '47.00', '49.0', '50.0'],
    "Spatial": ["74.8", "22.3/21.3", "15.5/20.0", "24.5/29.1", "26.2/30.7", "21.7/24.7", "29.0/33.0", 
                "28.2/32.9", "34.3/37.2", "43.3/45.5", "45.6/48.0", "48.5/50.4", "49.0/50.2", 
                "44.3/46.2", "32.2/36.2", "33.2/35.7", '34.0', '40.0', '46.0'],
    "Pattern Finding": ["88.6", "20.6/21.3", "16.7/20.0", "17.5/26.5", "21.5/29.6", "19.0/27.3", "20.3/29.6", 
                "18.6/26.6", "37.5/43.7", "29.5/34.8", "41.8/47.9", "43.3/47.8", "42.5/48.4", 
                "39.9/45.3", "29.9/36.1", "38.3/44.2", 'x', 'x', 'x'],
    "Average": ["77.1", "17.3/21.6", "8.41/20.0", "22.5/30.8", "21.6/29.9", "14.7/22.8", "25.9/35.5", 
                "24.5/33.0", "27.6/35.3", "29.4/37.4", "29.7/37.3", "40.0/47.2", "42.1/49.6", 
                "42.8/50.2", "27.3/36.4", "32.3/40.2", '45.29', '45.18', '38.94']
}

# DataFrame 생성
df = pd.DataFrame(data)

# 시각화 함수 정의
def visualize_table(df):
    fig, ax = plt.subplots(figsize=(12, 5))

    # 테이블 그리기
    ax.axis('off')
    table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

    # 스타일 설정
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.auto_set_column_width(col=list(range(len(df.columns))))

    # 헤더와 첫 행 배경 색상 설정
    num_row = len(df.values)
    for (i, j), cell in table.get_celld().items():
        if i == 0:
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor('#40466e')
        elif i == 1:
            cell.set_facecolor('#e8e8e8')
        elif i in [2,3]:
            cell.set_facecolor('#c9daf8ff')
        elif i >= (num_row+1-3):
            cell.set_facecolor('#f4ccccff')
        else:
            cell.set_facecolor('white')
        cell.set_edgecolor('#bdbdbd')

    plt.title('Supervised Setting Performance Table')
    plt.tight_layout()
    plt.show()

# 함수 실행
visualize_table(df)

# %%
def plot_pie_chart():
    """
    Train/Valid/Test 퍼즐 데이터를 파이 그래프로 시각화하는 함수
    """
    # 데이터
    labels = ['Train\n(230)', 'Valid\n(20)', 'Test\n(50)']
    sizes = [230, 20, 50]
    
    colors = ['lightblue', 'lightgreen', 'lightcoral']  # 각 카테고리 색상 지정
    explode = (0.1, 0, 0)  # Train 파이를 약간 띄워서 강조

    # 파이 그래프 그리기
    plt.figure(figsize=(7, 7))
    plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
            shadow=True, startangle=90, textprops={'fontsize': 12})
    
    # 원형 비율 유지
    plt.axis('equal')

    # 제목 추가
    plt.title('17 Train Puzzle Data Split', fontsize=16, fontweight='bold')

    # 그래프 출력
    plt.show()

# 함수 실행
plot_pie_chart()

# %%
def plot_pie_chart():
    """
    Train/Valid/Test 퍼즐 데이터를 파이 그래프로 시각화하는 함수
    """
    # 데이터
    labels = ['Test\n(300)']
    sizes = [300]
    colors = ['lightyellow']  # 각 카테고리 색상 지정

    # 파이 그래프 그리기
    plt.figure(figsize=(6, 6))
    plt.pie(sizes, labels=labels, colors=colors,
            shadow=True, startangle=90, textprops={'fontsize': 12})
    
    # 원형 비율 유지
    plt.axis('equal')

    # 제목 추가
    plt.title('3 ZeroShot Test Puzzle', fontsize=16, fontweight='bold')

    # 그래프 출력
    plt.show()

# 함수 실행
plot_pie_chart()

# %%
def plot_loss(train_loss, val_loss, epochs, len_step_per_epoch, save_path=None):

    # 그래프 그리기
    plt.figure(figsize=(10, 6))
    
    # 학습 로스
    plt.plot(list(map(int,list(train_loss.keys()))), list(train_loss.values()), 'b-', marker='o', label='Training Loss', linewidth=2)
    
    # 검증 로스
    plt.plot(list(map(int,list(valid_loss.keys()))), list(val_loss.values()), 'r-', marker='x', label='Validation Loss', linewidth=2)

    # 그래프 제목과 레이블 설정
    plt.title('Training and Validation Loss', fontsize=14, fontweight='bold')
    plt.xlabel('Steps', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    
    # 에포크 별 수렴 추이
    # Rectangle((x좌표, y좌표), 가로길이, 세로길이)
    max_value = max(list(val_loss.values()))
    for i in range(epochs):
        rect = patches.Rectangle((len_step_per_epoch*i,0), len_step_per_epoch, max_value, linewidth=0, edgecolor='none', facecolor=colors[i*9], alpha=0.1)
        plt.gca().add_patch(rect)

    # 범례 및 기타 설정
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.tight_layout()

    # # 저장 경로가 있으면 파일로 저장
    # plt.savefig(save_path, format='png', dpi=300)
    # print(f"Graph saved to {save_path}")

# %%
plot_loss(train_loss, valid_loss, 4, 120)
